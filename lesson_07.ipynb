# %% [markdown]
# # Lesson 7 - Functions
# In this lesson we'll learn:
#
# - What are functions and why we use them
# - How to define and call functions
# - Parameters and arguments
# - Return values
# - Variable scope
# - Documenting functions

# %% [markdown]
# ---
# ### Part 1: What is a Function?
# A function is a reusable block of code that performs a specific task. Functions help organize code and avoid repetition.
# Syntax:

# %%
def function_name():
    # code to run
    pass

# %% [markdown]
# Code cell:

# %%
# Define a simple function
def greet():
    print("Hello!")
    print("Welcome to Python")

# Call the function
greet()
greet()  # Can call multiple times

# %% [markdown]
# ---
# ### Part 2: Functions with Parameters
# Parameters let you pass information into functions.
# Code cell:

# %%
# Function with one parameter
def greet_person(name):
    print(f"Hello, {name}!")

greet_person("Alice")
greet_person("Bob")

# Function with multiple parameters
def introduce(name, age):
    print(f"My name is {name} and I am {age} years old")

introduce("Charlie", 15)
introduce("Diana", 16)

# %% [markdown]
# ---
# ### Part 3: Return Values
# Functions can send back a result using return.
# Code cell:

# %%
# Function that returns a value
def add(a, b):
    result = a + b
    return result

# Use the returned value
total = add(5, 3)
print(total)  # 8

print(add(10, 20))  # 30

# Function with calculation
def square(number):
    return number * number

print(square(5))   # 25
print(square(10))  # 100

# %% [markdown]
# ---
# ### Part 4: Functions with Default Parameters
# You can give parameters default values.
# Code cell:

# %%
# Default parameter
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet("Alice")    # Hello, Alice!
greet()           # Hello, Guest!

# Multiple defaults
def calculate_price(price, tax=0.08):
    total = price + (price * tax)
    return total

print(calculate_price(100))       # 108.0 (uses default tax)
print(calculate_price(100, 0.10)) # 110.0 (custom tax)

# %% [markdown]
# ---
# ### Part 5: Variable Scope
# Variables created inside functions are local - they only exist inside that function.
# Code cell:

# %%
# Local vs Global variables
total = 0  # Global variable

def add_numbers(a, b):
    result = a + b  # Local variable
    return result

answer = add_numbers(5, 3)
print(answer)  # 8
# print(result)  # This would cause an error - result doesn't exist here

# %% [markdown]
# ---
# ### Part 6: Documenting Functions
# Use docstrings (triple quotes) to document what a function does.
# Code cell:

# %%
def calculate_area(width, height):
    """
    Calculate the area of a rectangle.
    
    Parameters:
    width - the width of the rectangle
    height - the height of the rectangle
    
    Returns:
    The area as width * height
    """
    return width * height

# Use the function
area = calculate_area(5, 10)
print(area)

# View documentation
print(calculate_area.__doc__)

# %% [markdown]
# ---
# ### Important Notes
#
# - Use def to define a function
# - Function names should be lowercase with underscores
# - Parameters go in parentheses
# - Use return to send back a value
# - Call functions by using their name with parentheses
# - Functions make code reusable and organized

# %% [markdown]
# ---
# ### Practice Tasks

# %% [markdown]
# ### Task 1: Simple Functions
# Create these functions:
#
# - say_hello() - prints "Hello World"
# - print_line() - prints a line of dashes
# - Call each function twice
#
# Code cell:

# %%
# Your code here
def say_hello():
    print("hello world")

def print_line():
    print("__________")

say_hello()
say_hello()

print_line()
print_line()

# %% [markdown]
# ---
# ### Task 2: Functions with Parameters
# Create a function called calculate_rectangle() that:
#
# - Takes two parameters: width and height
# - Calculates the area
# - Prints the result
# - Call it with different values
#
# Code cell:

# %%
# Your code here
def calculate_rectangle(width, height):
    result = width * height
    print(result)

calculate_rectangle(3, 2)

calculate_rectangle(4, 8)

# %% [markdown]
# ---
# ### Task 3: Functions with Return
# Create these functions that return values:
#
# - multiply(a, b) - returns a * b
# - is_even(number) - returns True if even, False if odd
# - Test both functions
#
# Code cell:

# %%
# Your code here    
def multiply(a, b):
    result=a*b
    return result

def is_even(number):
    if number%2==0:
        return True
    else:
        return False
    
answer_1= multiply(6, 7)

answer_2=is_even(67)

print(answer_1)

print(answer_2)

# %% [markdown]
# ---
# ### Task 4: Temperature Converter
# Create a function celsius_to_fahrenheit(celsius) that:
#
# - Takes temperature in Celsius
# - Converts to Fahrenheit: F = C * 9/5 + 32
# - Returns the result
# - Test with values: 0, 25, 100
#
# Code cell:

# %%
# Your code here

def celsius_to_fahrenheit(celsius):
    f=celsius*9/5+32
    return f

answer_1=celsius_to_fahrenheit(0)

answer_2=celsius_to_fahrenheit(25)

answer_3=celsius_to_fahrenheit(100)

print(answer_1)

print(answer_2)

print(answer_3)

# %% [markdown]
# ---
# ### Task 5: Grade Calculator
# Create a function get_grade(score) that:
#
# 1. Takes a test score (0-100)
# 2. Returns the letter grade:
#
#     - 90-100: "A"
#     - 80-89: "B"
#     - 70-79: "C"
#     - 60-69: "D"
#     - Below 60: "F"
#
#
# 3. Test with different scores
#
# Code cell:

# %%
# Your code here

def get_grade(score):
    if 89<score and score<101:
        return "A"
    elif 79<score and score<90:
        return "B"
    elif 69<score and score<80:
        return "C"
    elif 59<score and score<70:
        return "D"
    elif score<60:
        return "F"

answer_1=get_grade(100)

answer_2=get_grade(85)

answer_3=get_grade(70)

answer_4=get_grade(67)

answer_5=get_grade(42)

print(answer_1)

print(answer_2)

print(answer_3)

print(answer_4)

print(answer_5)

# %% [markdown]
# ---
# ### Task 6: List Statistics (Challenge)
# Create a function analyze_list(numbers) that:
#
# 1. Takes a list of numbers as parameter
# 2. Calculates and returns three values:
#
#     - Sum of all numbers
#     - Average
#     - Count of numbers
#
#
# 3. Use the function with a list of test scores
#
# Hint: A function can return multiple values: return sum, avg, count

# %%
# Your code here

numbers=[67,42,56,96,12]

def analyze_list(numbers):
    sum_list = sum(numbers)
    len_list = len(numbers)
    avg_list = sum_list/len_list

    return sum_list, len_list, avg_list

sum_numbers, count_numbers, avg_numbers =analyze_list(numbers)

print(sum_numbers, count_numbers, avg_numbers)

# %% [markdown]
# ---
# ### Advanced Challenge (Optional)
# Create a mini calculator with these functions:
#
# 1. add(a, b) - returns sum
# 2. subtract(a, b) - returns difference
# 3. multiply(a, b) - returns product
# 4. divide(a, b) - returns quotient (check for division by zero)
# 5. calculator() - main function that:
#
#     - Shows menu
#     - Gets user input
#     - Calls appropriate function
#     - Displays result
#
#
#
# Code cell:

# %%
# Your challenge code here

def add(a, b):
    result=a+b
    return result

def subtract(a, b):
    result=a-b
    return result

def multiply(a, b):
    result=a*b
    return result

def divide(a, b):
    if b==0:
        return "error, can't devide by zero"
    
    result=a/b
    return result

def calculator():
    print("choose: 1-sum, 2-differnce, 3-product, 4-quetient")
    user_input = input("chosse operation: ")
    first_number_input = int(input("enter first number: "))
    second_number_input = int(input("enter second number: "))

    if user_input== "1":
        answer = add(first_number_input, second_number_input)
    elif user_input== "2":
        answer = subtract(first_number_input, second_number_input)
    elif user_input== "3":
        answer = multiply(first_number_input, second_number_input)
    elif user_input== "4":
        answer = divide(first_number_input, second_number_input)
    return answer

answer = calculator()
print(answer)

# %% [markdown]
# ---
# ### Lesson Summary
# What we learned today:
#
# - Functions are reusable blocks of code
# - Define with def function_name():
# - Parameters pass information into functions
# - return sends values back from functions
# - Default parameters provide fallback values
# - Variable scope: local vs global
# - Docstrings document what functions do
#
# Benefits of Functions:
#
# - Avoid repeating code
# - Make code more organized
# - Easier to test and debug
# - Code is more readable
#
# Next lesson: We'll learn about importing modules and creating graphics with Turtle

# %% [markdown]
# ---
# ### Homework
#
# 1. Math Functions:
#
#     - Create function power(base, exponent) - returns base raised to exponent
#     - Create function factorial(n) - returns n! (n * (n-1) * ... * 1)
#     - Test both functions
#
#
# 2. String Functions:
#
#     - Create function count_vowels(text) - counts a, e, i, o, u in text
#     - Create function reverse_string(text) - returns reversed string
#     - Test with different strings
#
#
# 3. Validation Functions:
#
#     - Create function is_valid_email(email) - checks if email contains @ and .
#     - Create function is_strong_password(password) - checks if at least 8 characters
#     - Test with valid and invalid inputs
#
#
#
# Code cell for homework:

# %%
# Space for your homework
def power(base, exsponent):
    result=base**exsponent
    return result

def factorial(n):
    result = 1
    for i in range(1, n+1):
        result *= i
    return result

answer_1=power(2, 4)

answer_2=factorial(5)

print(answer_1)

print(answer_2)

# %%
def count_vowels(text):
    result = len(text)
    return result

def reverse_string(text):
    result= text[::-1]
    return result

answer_1=count_vowels("hello")

answer_2=reverse_string("world")

answer_3=count_vowels("dog")

answer_4=reverse_string("cat")

print(answer_1)

print(answer_2)

print(answer_3)

print(answer_4)

# %%
def is_valid_email(email):
    if "." in email and "@" in email:
        return "valid"
    else:
        return "invalid"

def is_strong_password(password):
    if len(password) >= 8:
        return "valid"    
    else:
        return "invalid"
        
answer_1 = is_valid_email("shalom.feldman@gmail.com")

answer_2 = is_valid_email("shalom_feldman_gmail_com")

answer_3 = is_strong_password("ori.nof@gmail.com")

answer_4 = is_strong_password("ori.nof")

print(answer_1)

print(answer_2)

print(answer_3)

print(answer_4)
